# %%
#-------------------------------------
# Author: Sneha Reddy Aenugu
# Description: Solving Gridworld with
# spiking agent actor-critic
#------------------------------------

import numpy as np
import math
import argparse
import random
import itertools
import pdb
import pickle
from gridworld import GridWorld687
import copy
np.set_printoptions(precision=2)

action_set = {0:"AU", 1:"AD", 2:"AL", 3:"AR"}
improvement_array = []

# Class for actor-critic module
class ActorCritic():
    def __init__(self, epsilon, alpha, lda):
        self.epsilon = 0.01
        self.alpha = alpha
        self.gamma = 0.9
        self.lda = lda
        self.sigma = 10
        self.gw = GridWorld687()
        self.actors = [SpikingActor() for i in range(10)]

    def tabular_softmax(self, policy):
        softmax_policy = [np.exp(policy[i,:])/sum(np.exp(policy[i])) for i in range(policy.shape[0])]
        return softmax_policy

    def e_greedy_policy(self, action_ind):
        prob = (self.epsilon/4)*np.ones(4)
        prob[action_ind] = (1 - self.epsilon) + (self.epsilon/4)
        return prob

    def softmax_selection(self, qvalues, sigma):
        eps = 1e-5
        qvalues = qvalues + eps
        prob = np.exp(sigma*qvalues)/sum(np.exp(sigma*qvalues))
        return prob

    def run_actor_critic(self, num_episodes):
        returns = []
        weights_outer = []
        weights_inner = []
        theta = np.random.rand(101, 4)
        v_f = 10*np.random.rand(101)
        alpha = 0.1
        for i in range(num_episodes):
            rewards = []
            states = []
            states.append(0)
            state = 1
            e_theta = np.zeros_like(theta)
            e_v = np.zeros_like(v_f)
            gamma = 0.9
            count = 0
            while state != 100 and count < 300:
                # Act using actor
                actions = np.zeros((len(self.actors), 4))
                for k in range(len(self.actors)):
                    yo = self.actors[k].forward(state, count)
                    actions[k] = yo

                action_index = np.argmax(np.sum(actions, axis=0))

                prob = self.e_greedy_policy(action_index)
                attempt = int(np.random.choice(4, 1, p=prob))

                action = self.gw.action_from_attempt(action_set[attempt])
                if action != 'N':
                    action_ind = list(action_set.keys())[list(action_set.values()).index('A'+action)]
                else:
                    action_ind = attempt

                new_state = self.gw.transition_function(state, action)
                reward = self.gw.reward_function(new_state)


                # Critic update
                e_v *= gamma*self.lda
                e_v[state-1] += 1
                delta_t = reward + gamma*v_f[new_state-1] - v_f[state-1]
                v_f += alpha*delta_t*e_v


                # Actor update
                for k in range(len(self.actors)):
                    self.actors[k].update_weights(delta_t, state, action_ind, np.mean(rewards[-5:]))

                state = new_state
                count += 1
                rewards.append(reward)
                states.append(new_state)

            discounted_return = self.gw.get_discounted_returns(rewards)
            returns.append(discounted_return)
            # if i%20 == 0 or i==99:
            #     print("Discounted Return after %s episodes: %s" %(i, discounted_return))
            
            print("Discounted Return after %s episodes: %s" %(i, discounted_return))

        return returns



class SpikingActor():
    def __init__(self):
        self.inputs = 3
        self.hidden = 2
        self.outputs = 4

        self.ih = np.random.rand(4, self.hidden, self.inputs, 3)
        self.ho = np.random.rand(self.outputs, self.hidden, 3)
        self.vih = np.zeros((4, self.hidden, self.inputs, 3))
        self.vho = np.zeros((self.outputs, self.hidden, 3))

        self.input_map = self.state_coding()

    def state_coding(self):
        combns = list(itertools.combinations(range(5), r=2))
        maps = list(itertools.combinations(combns,r=3))
        return maps

    def input_coding(self, state):
        state_code = -1*np.ones((3,5))
        map_val = self.input_map[state]
        state_code[0,map_val[0]] = 1
        state_code[1,map_val[1]] = 1
        state_code[2,map_val[2]] = 1
        return state_code


    def sigmoid(self,x):
        return 1./(1 + np.exp(-2*x))


    def forward(self,state,count):
        
        inputs = self.input_coding(state)

        ph = np.zeros((4, self.hidden, 3))
        yh = np.zeros((4, self.hidden, 3))
        po = np.zeros(self.outputs)
        yo = np.zeros(self.outputs)
        dih = np.zeros((4, self.hidden, self.inputs,3))
        dho = np.zeros((self.outputs, self.hidden, 3))

        for i in range(4):
            for j in range(self.hidden):
                for k in range(self.inputs):
                    ph[i,j] = self.sigmoid(np.convolve(inputs[k],self.ih[i,j,k])[2:5])
                    yh[i,j] = (ph[i,j] > np.random.rand(3)).astype(int)
                    deriv = yh[i,j]*(1-ph[i,j]) + (1-yh[i,j])*(-ph[i,j])
                    dih[i,j,k,0] = np.sum(inputs[k,2:5]*deriv)
                    dih[i,j,k,1] = np.sum(inputs[k,1:4]*deriv)
                    dih[i,j,k,2] = np.sum(inputs[k,0:3]*deriv)
                    yh[i,j] = 2*yh[i,j] - 1


        for i in range(4):
            for j in range(self.hidden):
                po[i] = self.sigmoid(np.matmul(yh[i,j],self.ho[i,j]))
                yo[i] = (po[i] > np.random.rand(1)).astype(int)
                deriv = yo[i]*(1-po[i]) + (1-yo[i])*(-po[i])
                dho[i,j] = yo[i]*(1-po[i])*yh[i,j] + (-1)*(1-yo[i])*po[i]*yh[i,j]
                yo[i] = 2*yo[i] - 1
                    

        self.yo = yo
        self.yh = yh
        self.dih = dih
        self.dho = dho

        return yo

    
    def update_weights(self, tderror, state, action, count):
        if count < 0.4:
            alpha = 0.01
        else:
            alpha = 0.001
        self.beta = 0

        for i in range(4):
            if i == action and self.yo[i] > 0:
                dv = self.dih[i].copy()
                self.ih[i] += alpha*tderror*dv
            elif i == action and self.yo[i] < 0:
                self.ih[i] -= alpha*tderror*self.dih[i]
            elif i!= action and self.yo[i] < 0:
                self.ih[i] += alpha*tderror*self.dih[i]
            elif i!= action and self.yo[i] > 0:
                self.ih[i] -= alpha*tderror*self.dih[i]


        for i in range(4):
            if i == action and self.yo[i] > 0:
                dv = self.dho[i].copy()
                self.ho[i] += alpha*tderror*dv
            elif i == action and self.yo[i] < 0:
                self.ho[i] -= alpha*tderror*self.dho[i]
            elif i!= action and self.yo[i] < 0:
                self.ho[i] += alpha*tderror*self.dho[i]
            elif i!= action and self.yo[i] > 0:
                self.ho[i] -= alpha*tderror*self.dho[i]


class Args:
    algorithm = 'sarsa'
    selection = 'egreedy'
    num_trials = 1
    num_episodes = 1000
    plot = True
    num = 1


if __name__ == "__main__":

    args = Args()


    rewards_trials = []


    if args.selection == 'egreedy':
        step_size = 0.1 
        epsilon = 0.01
        lda = 0.7
    else:
        step_size = 0.1 
        epsilon = 0.1

    step_size = 0.1

    for i in range(int(args.num_trials)):
        print('Trial:', i)
        td_cp = ActorCritic(epsilon=epsilon, alpha=step_size, lda=lda)
        rewards = td_cp.run_actor_critic(int(args.num_episodes))

        rewards_trials.append(rewards)
    print("Maximum reward reached at the end of 100 episodes : ", np.mean(rewards_trials, axis=0)[-1] )

    f = open('rewards_' + str(args.num) + '.pkl', 'wb')
    pickle.dump(rewards_trials, f)
# Out:
# 650 episodes: 0.3815204244769461
# Discounted Return after 651 episodes: 0.0785516721127895
# Discounted Return after 652 episodes: 1.0941898913151242
# Discounted Return after 653 episodes: 0.9847709021836117
# Discounted Return after 654 episodes: 0.717897987691853
# Discounted Return after 655 episodes: 0.523347633027361
# Discounted Return after 656 episodes: 0.717897987691853
# Discounted Return after 657 episodes: 1.0941898913151242
# Discounted Return after 658 episodes: 1.3508517176729928
# Discounted Return after 659 episodes: 1.0941898913151242
# Discounted Return after 660 episodes: 0.7976644307687255
# Discounted Return after 661 episodes: 1.0941898913151242
# Discounted Return after 662 episodes: 0.6461081889226677
# Discounted Return after 663 episodes: 0.3433683820292515
# Discounted Return after 664 episodes: 0.8862938119652507
# Discounted Return after 665 episodes: 0.523347633027361
# Discounted Return after 666 episodes: 1.3508517176729928
# Discounted Return after 667 episodes: 0.5814973700304009
# Discounted Return after 668 episodes: 0.523347633027361
# Discounted Return after 669 episodes: 0.8862938119652507
# Discounted Return after 670 episodes: 0.717897987691853
# Discounted Return after 671 episodes: 0.6461081889226677
# Discounted Return after 672 episodes: 1.2157665459056934
# Discounted Return after 673 episodes: 1.2157665459056934
# Discounted Return after 674 episodes: 1.0941898913151242
# Discounted Return after 675 episodes: 1.2157665459056934
# Discounted Return after 676 episodes: 0.25031555049932436
# Discounted Return after 677 episodes: 1.5009463529699918
# Discounted Return after 678 episodes: 1.0941898913151242
# Discounted Return after 679 episodes: 0.9847709021836117
# Discounted Return after 680 episodes: 0.8862938119652507
# Discounted Return after 681 episodes: 0.3815204244769461
# Discounted Return after 682 episodes: 0.42391158275216234
# Discounted Return after 683 episodes: 1.2157665459056934
# Discounted Return after 684 episodes: 0.6461081889226677
# Discounted Return after 685 episodes: 0.5814973700304009
# Discounted Return after 686 episodes: 1.0941898913151242
# Discounted Return after 687 episodes: 0.717897987691853
# Discounted Return after 688 episodes: 1.5009463529699918
# Discounted Return after 689 episodes: 0.20275559590445275
# Discounted Return after 690 episodes: 0.717897987691853
# Discounted Return after 691 episodes: 0.717897987691853
# Discounted Return after 692 episodes: 0.9847709021836117
# Discounted Return after 693 episodes: 0.5814973700304009
# Discounted Return after 694 episodes: 1.0941898913151242
# Discounted Return after 695 episodes: 0.8862938119652507
# Discounted Return after 696 episodes: 0.5814973700304009
# Discounted Return after 697 episodes: 0.7976644307687255
# Discounted Return after 698 episodes: 1.5009463529699918
# Discounted Return after 699 episodes: 0.523347633027361
# Discounted Return after 700 episodes: 0.30903154382632636
# Discounted Return after 701 episodes: 0.717897987691853
# Discounted Return after 702 episodes: 0.717897987691853
# Discounted Return after 703 episodes: 1.3508517176729928
# Discounted Return after 704 episodes: 0.8862938119652507
# Discounted Return after 705 episodes: 1.6677181699666577
# Discounted Return after 706 episodes: 0.7976644307687255
# Discounted Return after 707 episodes: 0.6461081889226677
# Discounted Return after 708 episodes: 0.717897987691853
# Discounted Return after 709 episodes: 0.9847709021836117
# Discounted Return after 710 episodes: 0.8862938119652507
# Discounted Return after 711 episodes: 0.717897987691853
# Discounted Return after 712 episodes: 1.6677181699666577
# Discounted Return after 713 episodes: 1.3508517176729928
# Discounted Return after 714 episodes: 0.30903154382632636
# Discounted Return after 715 episodes: 0.717897987691853
# Discounted Return after 716 episodes: 0.3433683820292515
# Discounted Return after 717 episodes: 0.717897987691853
# Discounted Return after 718 episodes: 0.717897987691853
# Discounted Return after 719 episodes: 0.20275559590445275
# Discounted Return after 720 episodes: 1.0941898913151242
# Discounted Return after 721 episodes: 0.5814973700304009
# Discounted Return after 722 episodes: 1.0941898913151242
# Discounted Return after 723 episodes: 0.8862938119652507
# Discounted Return after 724 episodes: 1.2157665459056934
# Discounted Return after 725 episodes: 1.0941898913151242
# Discounted Return after 726 episodes: 1.0941898913151242
# Discounted Return after 727 episodes: 1.0941898913151242
# Discounted Return after 728 episodes: 1.0941898913151242
# Discounted Return after 729 episodes: 0.5814973700304009
# Discounted Return after 730 episodes: 0.717897987691853
# Discounted Return after 731 episodes: 0.22528399544939195
# Discounted Return after 732 episodes: 0.3815204244769461
# Discounted Return after 733 episodes: 0.7976644307687255
# Discounted Return after 734 episodes: 0.7976644307687255
# Discounted Return after 735 episodes: 1.0941898913151242
# Discounted Return after 736 episodes: 0.5814973700304009
# Discounted Return after 737 episodes: 0.9847709021836117
# Discounted Return after 738 episodes: 1.2157665459056934
# Discounted Return after 739 episodes: 0.717897987691853
# Discounted Return after 740 episodes: 0.3815204244769461
# Discounted Return after 741 episodes: 1.3508517176729928
# Discounted Return after 742 episodes: 0.5814973700304009
# Discounted Return after 743 episodes: 0.9847709021836117
# Discounted Return after 744 episodes: 1.0941898913151242
# Discounted Return after 745 episodes: 0.42391158275216234
# Discounted Return after 746 episodes: 1.0941898913151242
# Discounted Return after 747 episodes: 1.0941898913151242
# Discounted Return after 748 episodes: 1.0941898913151242
# Discounted Return after 749 episodes: 1.5009463529699918
# Discounted Return after 750 episodes: 0.8862938119652507
# Discounted Return after 751 episodes: 0.8862938119652507
# Discounted Return after 752 episodes: 0.8862938119652507
# Discounted Return after 753 episodes: 1.0941898913151242
# Discounted Return after 754 episodes: 0.5814973700304009
# Discounted Return after 755 episodes: 0.717897987691853
# Discounted Return after 756 episodes: 0.6461081889226677
# Discounted Return after 757 episodes: 1.0941898913151242
# Discounted Return after 758 episodes: 1.2157665459056934
# Discounted Return after 759 episodes: 0.42391158275216234
# Discounted Return after 760 episodes: 0.6461081889226677
# Discounted Return after 761 episodes: 1.3508517176729928
# Discounted Return after 762 episodes: 0.8862938119652507
# Discounted Return after 763 episodes: 0.8862938119652507
# Discounted Return after 764 episodes: 0.1824800363140075
# Discounted Return after 765 episodes: 0.9847709021836117
# Discounted Return after 766 episodes: 0.7976644307687255
# Discounted Return after 767 episodes: 0.30903154382632636
# Discounted Return after 768 episodes: 1.0941898913151242
# Discounted Return after 769 episodes: 0.5814973700304009
# Discounted Return after 770 episodes: 0.25031555049932436
# Discounted Return after 771 episodes: 0.5814973700304009
# Discounted Return after 772 episodes: 0.8862938119652507
# Discounted Return after 773 episodes: 0.6461081889226677
# Discounted Return after 774 episodes: 0.7976644307687255
# Discounted Return after 966 episodes: 0.717897987691853
# Discounted Return after 967 episodes: 0.3433683820292515
# Discounted Return after 968 episodes: 0.42391158275216234
# Discounted Return after 969 episodes: 0.7976644307687255
# Discounted Return after 970 episodes: 0.20275559590445275
# Discounted Return after 971 episodes: 0.3815204244769461
# Discounted Return after 972 episodes: 1.0941898913151242
# Discounted Return after 973 episodes: 0.9847709021836117
# Discounted Return after 974 episodes: 0.02738927449953412
# Discounted Return after 975 episodes: 0.25031555049932436
# Discounted Return after 976 episodes: 0.8862938119652507
# Discounted Return after 977 episodes: 1.0941898913151242
# Discounted Return after 978 episodes: 0.42391158275216234
# Discounted Return after 979 episodes: 0.20275559590445275
# Discounted Return after 980 episodes: 0.2781283894436937
# Discounted Return after 981 episodes: 0.6461081889226677
# Discounted Return after 982 episodes: 0.8862938119652507
# Discounted Return after 983 episodes: 0.6461081889226677
# Discounted Return after 984 episodes: 0.6461081889226677
# Discounted Return after 985 episodes: 0.3433683820292515
# Discounted Return after 986 episodes: 0.6461081889226677
# Discounted Return after 987 episodes: 0.10775263664305829
# Discounted Return after 988 episodes: 0.6461081889226677
# Discounted Return after 989 episodes: 0.8862938119652507
# Discounted Return after 990 episodes: 0.2781283894436937
# Discounted Return after 991 episodes: 1.3508517176729928
# Discounted Return after 992 episodes: 0.9847709021836117
# Discounted Return after 993 episodes: 0.8862938119652507
# Discounted Return after 994 episodes: 1.2157665459056934
# Discounted Return after 995 episodes: 0.5814973700304009
# Discounted Return after 996 episodes: 0.25031555049932436
# Discounted Return after 997 episodes: 0.8862938119652507
# Discounted Return after 998 episodes: 0.9847709021836117
# Discounted Return after 999 episodes: 0.5814973700304009
# Maximum reward reached at the end of 100 episodes :  0.5814973700304009

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()

episodes = np.linspace(0,int(args.num_episodes)-1,int(args.num_episodes))
Rm = np.array(rewards_trials).reshape(-1)
mean_rewards = []
std_rewards = []
for i in range(len(Rm)):
    mean_rewards.append(np.mean(Rm[:(i+1)]))
    std_rewards.append(np.std(Rm[:(i+1)]))
mean_rewards = np.array(mean_rewards)
std_rewards = np.array(std_rewards)

p0 = figure(
    title = "Rewards (Gridworld)",
    x_axis_label = "Episodes",
    y_axis_label = "Rewards"
)
p0.line(x=episodes, y=Rm, line_width=2)

p1 = figure(
    title = "Mean rewards (Gridworld)",
    x_axis_label = "Episodes",
    y_axis_label = "Mean Rewards"
)
p1.line(x=episodes, y=mean_rewards, line_width=2)

p2 = figure(
    title = "Standard deviation of rewards (Gridworld)",
    x_axis_label = "Episodes",
    y_axis_label = "Standard Deviation of Rewards"
)
p2.line(x=episodes, y=std_rewards, line_width=2, color='red')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1683">Loading BokehJS ...</span>
#     </div>
# GlyphRenderer(id='1796', ...)

# %%
show(p0)
# Out:
#   <div class="bk-root" id="c1266de2-4163-477c-8d27-13c447bf2f35" data-root-id="1684"></div>

# %%
show(p1)
# Out:
#   <div class="bk-root" id="1a4755eb-a4b4-401e-a111-a8a37a9f5397" data-root-id="1722"></div>

# %%
show(p2)
# Out:
#   <div class="bk-root" id="7da63a85-1e70-4c51-befa-4cfef3d1a2f2" data-root-id="1760"></div>
