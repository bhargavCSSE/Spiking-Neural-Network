# %%
import numpy as np

# %%
hidden = 200
inputs = 4
outputs = 2
h_spikes = np.ones((2, hidden))
ih_weights = 0.01*np.random.rand(2, hidden, inputs)

# %%
ih_weights[1]
# Out:
# array([[8.34518102e-03, 3.37873641e-03, 3.30727166e-03, 2.32005868e-03],
#        [6.09983708e-03, 1.00698394e-03, 1.60447621e-04, 8.16645947e-03],
#        [9.14487590e-03, 8.10637724e-03, 3.26850911e-03, 6.44818328e-04],
#        [7.57727627e-03, 5.68260092e-03, 8.05517774e-03, 6.52971619e-03],
#        [2.64286639e-03, 9.18492116e-04, 9.69070319e-03, 6.96632567e-03],
#        [8.11302196e-03, 6.41537851e-03, 4.62142725e-03, 1.98150165e-03],
#        [5.21534902e-03, 9.38633988e-03, 9.26836651e-03, 1.79448192e-03],
#        [4.21933728e-04, 7.80815816e-03, 1.79780062e-03, 1.86800607e-03],
#        [7.73779887e-03, 9.08762562e-05, 6.16622442e-03, 9.17002247e-04],
#        [5.43980217e-03, 8.99050080e-03, 8.11353588e-03, 3.91410492e-03],
#        [2.80614941e-03, 8.74207875e-03, 9.93407322e-03, 6.14043866e-03],
#        [2.31863041e-03, 5.14308586e-03, 1.86740381e-03, 4.29777263e-03],
#        [9.91599930e-03, 3.36182651e-03, 7.99708672e-03, 7.12088097e-03],
# ...
